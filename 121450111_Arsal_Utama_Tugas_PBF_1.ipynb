# %% [markdown]
# # PBF Assignment Week 1

# %% [markdown]
# ## Muhammad Arsal Ranjana Utama
# ## 121450111
# ## RA

# %% [markdown]
# ### Soal 1. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural dibandingkan dengan object oriented (minimal 3) !

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame({'Kelebihan' : ['Mudah dipahami dan diterapkan', 'Performa yang lebih baik', 'Kode modular.'],
        'Kekurangan' : ['Penggunaan kembali kode yang terbatas', 'Kurangnya enkapsulasi', 'Kesulitan dalam memodelkan sistem yang kompleks']
        })

df = data

#initialize figure
fig = plt.figure(figsize = (10, .02))
ax = fig.add_subplot(111)

#create table
ax.table(cellText = df.values, rowLabels = df.index, 
         colLabels = df.columns, cellLoc='center')

#add title to table
ax.set_title('Kelebihan dan Kekurangan Paradigma Procedural Dibandingkan dengan Object Oriented')

#turn axes off
ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# ### Soal 2. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma object oriented dibandingkan dengan functional (minimal 3) !

# %%
data1 = pd.DataFrame({'Kelebihan' : ['Enkapsulasi, Objek dapat menyembunyikan data dan metode mereka di balik antarmuka publik', 'Dapat digunakan kembali, Kelas dapat digunakan sebagai blok penyusun untuk kelas lain', 'Inheritence,  Kelas yang dapat mewarisi properti dan perilaku dari kelas induk.', 'Polimorfisme, Kemampuan objek untuk mengambil bentuk yang berbeda berdasarkan konteks'],
        'Kekurangan' : ['Object-oriented programming dapat menghasilkan sistem yang lebih kompleks yang lebih sulit untuk dipahami dan dipelihara karena berbagai tingkat abstraksinya.', 'Rigidity/Kekakuan: Fitur enkapsulasi dan pewarisan dapat menyebabkan sistem yang kaku dan sulit diubah.', 'Kinerja, Object-oriented programming bisa lebih lambat daripada sistem fungsional karena overhead pengiriman metode dan alokasi objek.','---']
        })

df = data1

#initialize figure
fig = plt.figure(figsize = (25, .02))
ax = fig.add_subplot(111)

#create table
ax.table(cellText = df.values, rowLabels = df.index, 
         colLabels = df.columns, cellLoc='center')

#add title to table
ax.set_title('Kelebihan dan Kekurangan Paradigma Object Oriented Dibandingkan dengan Functional')

#turn axes off
ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# ### Soal 3. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural dibandingkan dengan functional (minimal 3) !

# %%
data2 = pd.DataFrame({'Kelebihan' : ['Mudah dipahami dan diterapkan untuk pemula.', 'Control flow structure,  yang lebih baik, membuatnya lebih mudah untuk menangani pernyataan bersyarat dan loop.', 'Baik untuk memecahkan masalah yang dapat dipecah menjadi langkah-langkah yang lebih kecil dan dapat dikelola.'],
        'Kekurangan' : ['Penanganan yang buruk terhadap struktur data yang kompleks, membuatnya lebih sulit untuk mengelola data dalam jumlah besar.', 'Kurangnya modularitas dan penggunaan kembali, membuatnya lebih sulit untuk memelihara dan memperbarui kode.', 'Lebih rentan terhadap bug dan kesalahan, terutama dengan basis kode yang lebih besar.']
        })

df = data2

#initialize figure
fig = plt.figure(figsize = (20, .5))
ax = fig.add_subplot(111)

#create table
ax.table(cellText = df.values, rowLabels = df.index, 
         colLabels = df.columns, cellLoc='center')

#add title to table
ax.set_title('Kelebihan dan Kekurangan Paradigma Object Oriented Dibandingkan dengan Functional')

#turn axes off
ax.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# ### Soal 4. Apa yang dimaksud dengan pure functional programming language?

# %% [markdown]
# #### Bahasa pemrograman fungsional murni adalah paradigma pemrograman yang menekankan penggunaan fungsi yang tidak memiliki efek samping dan hanya bergantung pada inputnya untuk menghasilkan output. Dalam bahasa fungsional murni, fungsi diperlakukan sebagai entitas matematika, dan semua fungsi bersifat deterministik, artinya input yang sama akan selalu menghasilkan output yang sama. Ini membuat program fungsional lebih mudah untuk dipikirkan, diuji, dan diparalelkan. Contoh bahasa pemrograman fungsional murni termasuk Haskell, Skema, dan ML.

# %% [markdown]
# ### Soal 5. Dari bahasa pemrograman FP di slide sebelumnya ( slide 14 ) , manakah yang termasuk pure functional programming language?

# %% [markdown]
# #### Lisp, Javasript, Haskell

# %% [markdown]
# ### Soal 6. Membuat program Simple Password encryption, dengan ketentuan
#             1. Input password bertipe string dengan batasan panjang password 100 karakter
#             2. Setiap karakter dari string tersebut diubah menjadi ASCII value
#             3. Kemudian setiap ASCII value tersebut dikembangkan menjadi 3 value dengan dilakukan operasi berikut:
#              . Value pertama dibagi dengan integer 26 kemudian dibulatkan dan dijumlahkan dengan 80 kemudian diubah kembali menjadi karakter
#              . Value kedua dihitung sisa bagi dengan 26 kemudian dijumlahkan dengan 80 kemudian diubah kembali menjadi karakter
#              . Value ketiga adalah karakter ‘+’ jika value pertama lebih besar dari value kedua, atau value ketiga adalah karakter ‘-’ jika value pertama tidak lebih besar dari value kedua
#             4. Deretkan value pertama, kedua dan ketiga untuk setiap karakter dalam password tersebut sehingga didapatkan password dalam bentuk baru

# %%
def encrypt_password(password):
    encrypted = ""
    for char in password:
        ascii_val = ord(char)
        first = (ascii_val // 26) + 80
        second = (ascii_val % 26) + 80
        third = '+' if first > second else '-'
        encrypted += chr(first) + chr(second) + third
    return encrypted

password = input("Enter password: ")

if len(password) > 100:
    print("Password cannot exceed 100 characters")
else:
    encrypted_password = encrypt_password(password)
    print("Encrypted password:", encrypted_password)
# Out:
# Enter password: ArsalU
# Encrypted password: R]-TZ-T[-Sc-TT-SW-
